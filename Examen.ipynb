# %%
import funciones_examen as fn

# %% [markdown]
# ## **Función 1. Carga de archivos**

# %%
df=fn.cargar_dataset("Rio.csv")
df.head()
# Out:
#         source                                   name  host_since  \
# 0  city scrape      Unbelievable Ocean View Apartment  2011-11-19
# 1  city scrape    EXCELENTE APARTAMENTO EM COPACABANA  2013-07-15
# 2  city scrape                  Comfort em Copacabana  2011-11-20
# 3  city scrape       Amazing Huge Apartment in Leblon  2011-04-25
# 4  city scrape  Lindo quarto sossegado para temporada  2011-05-04
#
#             host_location  host_response_time host_response_rate  \
# 0  Rio de Janeiro, Brazil  a few days or more                 0%
# 1  Rio de Janeiro, Brazil                 NaN                NaN
# 2  Rio de Janeiro, Brazil      within an hour               100%
# 3  Rio de Janeiro, Brazil                 NaN                NaN
# 4  Rio de Janeiro, Brazil  within a few hours               100%
#
#   host_acceptance_rate host_is_superhost host_neighbourhood  \
# 0                   0%                 f            Vidigal
# 1                  NaN                 f                NaN
# 2                 100%                 t         Copacabana
# 3                  NaN                 f             Leblon
# 4                  20%                 f       Santa Teresa
#
#    host_listings_count  ...  review_scores_checkin  \
# 0                  1.0  ...                   4.33
# 1                  3.0  ...                   4.97
# 2                  6.0  ...                   4.94
# 3                  1.0  ...                    NaN
# 4                  5.0  ...                   5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.67                   4.33                4.00
# 1                        4.97                   4.97                4.86
# 2                        5.00                   4.97                4.94
# 3                         NaN                    NaN                 NaN
# 4                        5.00                   4.60                4.80
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              1
# 1                t                              2
# 2                t                              5
# 3                f                              1
# 4                f                              5
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            2
# 2                                            3
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             2
# 3                                             0
# 4                                             5
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.05
# 1                                            0               2.31
# 2                                            0               0.25
# 3                                            0                NaN
# 4                                            0               0.04
#
# [5 rows x 50 columns]

# %%
fn.cuenta_valores_nulos(df)
# Out:
# ('Valores nulos por columna:',
#  source                                              0
#  name                                                0
#  host_since                                          2
#  host_location                                    7646
#  host_response_time                               3921
#  host_response_rate                               3921
#  host_acceptance_rate                             3534
#  host_is_superhost                                1170
#  host_neighbourhood                               5535
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              2
#  neighbourhood                                   22619
#  neighbourhood_cleansed                              0
#  property_type                                       0
#  room_type                                           0
#  accommodates                                        0
#  bathrooms                                        2890
#  bedrooms                                          523
#  beds                                             2869
#  price                                            2855
#  minimum_nights                                      0
#  maximum_nights                                      0
#  minimum_minimum_nights                              0
#  maximum_minimum_nights                              0
#  minimum_maximum_nights                              0
#  maximum_maximum_nights                              0
#  has_availability                                  497
#  availability_30                                     0
#  availability_60                                     0
#  availability_90                                     0
#  availability_365                                    0
#  number_of_reviews                                   0
#  number_of_reviews_ltm                               0
#  number_of_reviews_l30d                              0
#  first_review                                    10419
#  last_review                                     10419
#  review_scores_rating                            10419
#  review_scores_accuracy                          10420
#  review_scores_cleanliness                       10419
#  review_scores_checkin                           10420
#  review_scores_communication                     10420
#  review_scores_location                          10421
#  review_scores_value                             10420
#  instant_bookable                                    0
#  calculated_host_listings_count                      0
#  calculated_host_listings_count_entire_homes         0
#  calculated_host_listings_count_private_rooms        0
#  calculated_host_listings_count_shared_rooms         0
#  reviews_per_month                               10419
#  dtype: int64,
#  'Valores nulos por dataframe: ',
#  162184)

# %% [markdown]
# ## **Función 2. Sustituye valores nulos**

# %%
df=fn.sustitución_nulos(df)
df.head()
# Out:
#    host_listings_count  bedrooms  minimum_minimum_nights  availability_30  \
# 0                  1.0       2.0                       1                0
# 1                  3.0       1.0                       1                4
# 2                  6.0       1.0                       2               26
# 3                  1.0       3.0                       2               30
# 4                  5.0       1.0                      60                0
#
#    number_of_reviews  review_scores_accuracy  review_scores_location  \
# 0                  7                    4.33                    4.33
# 1                367                    4.91                    4.97
# 2                 32                    5.00                    4.97
# 3                  0                    4.80                    4.90
# 4                  5                    5.00                    4.60
#
#    calculated_host_listings_count_private_rooms  host_total_listings_count  \
# 0                                             0                        3.0
# 1                                             0                        3.0
# 2                                             2                        6.0
# 3                                             0                        2.0
# 4                                             5                        6.0
#
#    beds  ...  host_identity_verified           neighbourhood  \
# 0   2.0  ...                       t  Rio de Janeiro, Brazil
# 1   1.0  ...                       f  Rio de Janeiro, Brazil
# 2   2.0  ...                       t   Este_es_un_valor_nulo
# 3   3.0  ...                       f   Este_es_un_valor_nulo
# 4   1.0  ...                       t  Rio de Janeiro, Brazil
#
#    neighbourhood_cleansed                property_type        room_type  \
# 0                 Vidigal           Entire rental unit  Entire home/apt
# 1              Copacabana           Entire rental unit  Entire home/apt
# 2              Copacabana  Private room in rental unit     Private room
# 3                  Leblon           Entire rental unit  Entire home/apt
# 4            Santa Teresa         Private room in home     Private room
#
#        price  has_availability           first_review            last_review  \
# 0    $236.00                 t             2013-02-16             2019-10-05
# 1    $723.00                 t             2011-12-06             2024-12-14
# 2  $1,146.00                 t             2014-07-01             2024-05-06
# 3  $6,742.00                 t  Este_es_un_valor_nulo  Este_es_un_valor_nulo
# 4     $61.00                 t             2015-03-11             2024-06-22
#
#    instant_bookable
# 0                 f
# 1                 t
# 2                 t
# 3                 f
# 4                 f
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Función 3. **Indentifica valores nulos**

# %%
fn.cuenta_valores_nulos(df)
# Out:
# ('Valores nulos por columna:',
#  host_listings_count                             0
#  bedrooms                                        0
#  minimum_minimum_nights                          0
#  availability_30                                 0
#  number_of_reviews                               0
#  review_scores_accuracy                          0
#  review_scores_location                          0
#  calculated_host_listings_count_private_rooms    0
#  host_total_listings_count                       0
#  beds                                            0
#  maximum_minimum_nights                          0
#  availability_60                                 0
#  number_of_reviews_ltm                           0
#  review_scores_cleanliness                       0
#  review_scores_value                             0
#  calculated_host_listings_count_shared_rooms     0
#  accommodates                                    0
#  minimum_nights                                  0
#  minimum_maximum_nights                          0
#  availability_90                                 0
#  number_of_reviews_l30d                          0
#  review_scores_checkin                           0
#  calculated_host_listings_count                  0
#  reviews_per_month                               0
#  bathrooms                                       0
#  maximum_nights                                  0
#  maximum_maximum_nights                          0
#  availability_365                                0
#  review_scores_rating                            0
#  review_scores_communication                     0
#  calculated_host_listings_count_entire_homes     0
#  source                                          0
#  name                                            0
#  host_since                                      0
#  host_location                                   0
#  host_response_time                              0
#  host_response_rate                              0
#  host_acceptance_rate                            0
#  host_is_superhost                               0
#  host_neighbourhood                              0
#  host_identity_verified                          0
#  neighbourhood                                   0
#  neighbourhood_cleansed                          0
#  property_type                                   0
#  room_type                                       0
#  price                                           0
#  has_availability                                0
#  first_review                                    0
#  last_review                                     0
#  instant_bookable                                0
#  dtype: int64,
#  'Valores nulos por dataframe: ',
#  0)

# %% [markdown]
# ## **Función 4. Valores atípicos**

# %%
df=fn.valores_atipicos(df)
# Out:
# Limite superior permitido host_listings_count                               14.750
# bedrooms                                           3.500
# minimum_minimum_nights                             6.000
# availability_30                                   55.500
# number_of_reviews                                 62.500
# review_scores_accuracy                             5.300
# review_scores_location                             5.150
# calculated_host_listings_count_private_rooms       2.500
# host_total_listings_count                         21.000
# beds                                               6.000
# maximum_minimum_nights                             9.500
# availability_60                                  114.000
# number_of_reviews_ltm                             25.000
# review_scores_cleanliness                        240.300
# review_scores_value                              240.390
# calculated_host_listings_count_shared_rooms        0.000
# accommodates                                       9.500
# minimum_nights                                     6.000
# minimum_maximum_nights                          2679.000
# availability_90                                  159.000
# number_of_reviews_l30d                             2.500
# review_scores_checkin                              5.150
# calculated_host_listings_count                    11.000
# reviews_per_month                                  2.495
# bathrooms                                          3.500
# maximum_nights                                   822.500
# maximum_maximum_nights                          2677.500
# availability_365                                 698.000
# review_scores_rating                             240.255
# review_scores_communication                      240.105
# calculated_host_listings_count_entire_homes        8.500
# dtype: float64
# Limite inferior permitido host_listings_count                               -7.250
# bedrooms                                          -0.500
# minimum_minimum_nights                            -2.000
# availability_30                                  -28.500
# number_of_reviews                                -37.500
# review_scores_accuracy                             4.500
# review_scores_location                             4.750
# calculated_host_listings_count_private_rooms      -1.500
# host_total_listings_count                        -11.000
# beds                                              -2.000
# maximum_minimum_nights                            -2.500
# availability_60                                  -46.000
# number_of_reviews_ltm                            -15.000
# review_scores_cleanliness                       -136.500
# review_scores_value                             -136.650
# calculated_host_listings_count_shared_rooms        0.000
# accommodates                                      -2.500
# minimum_nights                                    -2.000
# minimum_maximum_nights                         -1465.000
# availability_90                                  -49.000
# number_of_reviews_l30d                            -1.500
# review_scores_checkin                              4.750
# calculated_host_listings_count                    -5.000
# reviews_per_month                                 -0.905
# bathrooms                                         -0.500
# maximum_nights                                  -397.500
# maximum_maximum_nights                         -1462.500
# availability_365                                -302.000
# review_scores_rating                            -136.425
# review_scores_communication                     -136.175
# calculated_host_listings_count_entire_homes       -3.500
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df=fn.valores_atipicos(df)
#
# File ~/Desktop/Concentracion Freddy/Actividades/funciones_examen.py:70, in valores_atipicos(dataframe)
#      68 data4_iqr=data3_iqr.copy()
#      69 data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
# ---> 70 Datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
#      71 return Datos_limpios
#
# NameError: name 'cualitativas' is not defined
